# %% [markdown]
# # Diffusion model training

# %% [markdown]
# #### This notebook aims to launch the training of the main diffusion model. It does not train the classifier and regressor that are used to perform *classifier* and *regressor guidance*. The trainings of the three models (diffusion model, regressor and classifier) are independant.

# %%
import torch as th
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %% [markdown]
# The environment variable 'TOPODIFF_LOGDIR' defines the directory where the logs and model checkpoints will be saved.

# %%
os.environ['TOPODIFF_LOGDIR'] = './checkpoints/diff_logdir_train1564(32channel)'

# %% [markdown]
# The 'TRAIN FLAGS', 'MODEL_FLAGS', 'DIFFUSION_FLAGS' and 'DATA_FLAGS' respectively set the training parameters, the model and diffusion hyperparameters and the directories where the training data are.
#
# The default values indicated below correspond to the hyperparameters indicated in the Appendix to the paper.

# %%
TRAIN_FLAGS="--batch_size 32 --save_interval 5000 --use_fp16 True"
MODEL_FLAGS="--image_size 64 --num_channels 32 --num_res_blocks 1 --learn_sigma True --dropout 0.4"
DIFFUSION_FLAGS="--diffusion_steps 1000 --noise_schedule cosine"

# %% [markdown]
# In order to run the training, make sure you have placed the data folder at the root of this directory.
#
# All the images, physical fields, and load arrays must be altogether in the same folder (done by default in the data directory that we provide you with).

# %%
DATA_FLAGS="--data_dir ./data/flow_channels_1764_train"

# %%
# %run scripts/image_train.py $MODEL_FLAGS $DIFFUSION_FLAGS $TRAIN_FLAGS $DATA_FLAGS
# Out:
# Logging to ./checkpoints/diff_logdir_train1564(32channel)
# creating model and diffusion...
# creating data loader...
# training...
# ----------------------------
# | grad_norm     | 3.63     |
# | lg_loss_scale | 20       |
# | loss          | 1.02     |
# | mse           | 1.01     |
# | param_norm    | 80       |
# | samples       | 32       |
# | step          | 0        |
# | vb            | 0.0116   |
# ----------------------------
# saving model 0...
# saving model 0.9999...
# ----------------------------
# | grad_norm     | 3.5      |
# | lg_loss_scale | 20       |
# | loss          | 3.1      |
# | mse           | 0.969    |
# | param_norm    | 80.1     |
# | samples       | 352      |
# | step          | 10       |
# | vb            | 2.13     |
# ----------------------------
# ----------------------------
# | grad_norm     | 4.01     |
# | lg_loss_scale | 20       |
# | loss          | 0.906    |
# | mse           | 0.894    |
# | param_norm    | 80.1     |
# | samples       | 672      |
# | step          | 20       |
# | vb            | 0.0119   |
# ----------------------------
# ----------------------------
# | grad_norm     | 3.96     |
# | lg_loss_scale | 20       |
# | loss          | 2.46     |
# | mse           | 0.811    |
# | param_norm    | 80.1     |
# | samples       | 992      |
# | step          | 30       |
# | vb            | 1.65     |
# ----------------------------
# ----------------------------
# | grad_norm     | 3.78     |
# | lg_loss_scale | 20       |
# | loss          | 0.752    |
# | mse           | 0.737    |
# | param_norm    | 80.1     |
# | samples       | 1.31e+03 |
# | step          | 40       |
# | vb            | 0.0145   |
# ----------------------------
# ----------------------------
# | grad_norm     | 3.69     |
# | lg_loss_scale | 20       |
# | loss          | 0.667    |
# | mse           | 0.653    |
# | param_norm    | 80.1     |
# | samples       | 1.63e+03 |
# | step          | 50       |
# | vb            | 0.0148   |
# ----------------------------
# ----------------------------
# | grad_norm     | 3.39     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.608    |
# | mse           | 0.593    |
# | param_norm    | 80.1     |
# | samples       | 1.95e+03 |
# | step          | 60       |
# | vb            | 0.0154   |
# ----------------------------
# ----------------------------
# | grad_norm     | 3.17     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.539    |
# | mse           | 0.527    |
# | param_norm    | 80.1     |
# | samples       | 2.27e+03 |
# | step          | 70       |
# | vb            | 0.0115   |
# ----------------------------
# ----------------------------
# | grad_norm     | 2.99     |
# | lg_loss_scale | 20.1     |
# | loss          | 1.46     |
# | mse           | 0.464    |
# | param_norm    | 80.1     |
# | samples       | 2.59e+03 |
# | step          | 80       |
# | vb            | 1        |
# ----------------------------
# ----------------------------
# | grad_norm     | 2.81     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.412    |
# | mse           | 0.404    |
# | param_norm    | 80.1     |
# | samples       | 2.91e+03 |
# | step          | 90       |
# | vb            | 0.00779  |
# ----------------------------
# ----------------------------
# | grad_norm     | 2.57     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.372    |
# | mse           | 0.365    |
# | param_norm    | 80.1     |
# | samples       | 3.23e+03 |
# | step          | 100      |
# | vb            | 0.00691  |
# ----------------------------
# ----------------------------
# | grad_norm     | 2.35     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.325    |
# | mse           | 0.319    |
# | param_norm    | 80.1     |
# | samples       | 3.55e+03 |
# | step          | 110      |
# | vb            | 0.00608  |
# ----------------------------
# ----------------------------
# | grad_norm     | 2.14     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.307    |
# | mse           | 0.299    |
# | param_norm    | 80.1     |
# | samples       | 3.87e+03 |
# | step          | 120      |
# | vb            | 0.00822  |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.99     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.642    |
# | mse           | 0.249    |
# | param_norm    | 80.1     |
# | samples       | 4.19e+03 |
# | step          | 130      |
# | vb            | 0.393    |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.76     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.258    |
# | mse           | 0.25     |
# | param_norm    | 80.1     |
# | samples       | 4.51e+03 |
# | step          | 140      |
# | vb            | 0.00815  |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.62     |
# | lg_loss_scale | 20.1     |
# | loss          | 0.214    |
# | mse           | 0.206    |
# | param_norm    | 80.2     |
# | samples       | 4.83e+03 |
# | step          | 150      |
# | vb            | 0.00752  |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.45     |
# | lg_loss_scale | 20.2     |
# | loss          | 0.199    |
# | mse           | 0.194    |
# | param_norm    | 80.2     |
# | samples       | 5.15e+03 |
# | step          | 160      |
# | vb            | 0.0042   |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.38     |
# | lg_loss_scale | 20.2     |
# | loss          | 0.41     |
# | mse           | 0.187    |
# | param_norm    | 80.2     |
# | samples       | 5.47e+03 |
# | step          | 170      |
# | vb            | 0.223    |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.2      |
# | lg_loss_scale | 20.2     |
# | loss          | 0.165    |
# | mse           | 0.161    |
# | param_norm    | 80.2     |
# | samples       | 5.79e+03 |
# | step          | 180      |
# | vb            | 0.00371  |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.08     |
# | lg_loss_scale | 20.2     |
# | loss          | 0.156    |
# | mse           | 0.153    |
# | param_norm    | 80.2     |
# | samples       | 6.11e+03 |
# | step          | 190      |
# | vb            | 0.00333  |
# ----------------------------
# ----------------------------
# | grad_norm     | 1.07     |
# | lg_loss_scale | 20.2     |
# | loss          | 0.163    |
# | mse           | 0.157    |
# | param_norm    | 80.2     |
# | samples       | 6.43e+03 |
# | step          | 200      |
# | vb            | 0.00633  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.92     |
# | lg_loss_scale | 20.2     |
# | loss          | 0.128    |
# | mse           | 0.126    |
# | param_norm    | 80.2     |
# | samples       | 6.75e+03 |
# | step          | 210      |
# | vb            | 0.00209  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.798    |
# | lg_loss_scale | 20.2     |
# | loss          | 0.133    |
# | mse           | 0.127    |
# | param_norm    | 80.2     |
# | samples       | 7.07e+03 |
# | step          | 220      |
# | vb            | 0.0059   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.724    |
# | lg_loss_scale | 20.2     |
# | loss          | 0.131    |
# | mse           | 0.124    |
# | param_norm    | 80.2     |
# | samples       | 7.39e+03 |
# | step          | 230      |
# | vb            | 0.00641  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.684    |
# | lg_loss_scale | 20.2     |
# | loss          | 0.123    |
# | mse           | 0.119    |
# | param_norm    | 80.3     |
# | samples       | 7.71e+03 |
# | step          | 240      |
# | vb            | 0.004    |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.726    |
# | lg_loss_scale | 20.2     |
# | loss          | 0.108    |
# | mse           | 0.106    |
# | param_norm    | 80.3     |
# | samples       | 8.03e+03 |
# | step          | 250      |
# | vb            | 0.00185  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.675    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.186    |
# | mse           | 0.106    |
# | param_norm    | 80.3     |
# | samples       | 8.35e+03 |
# | step          | 260      |
# | vb            | 0.0797   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.761    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.17     |
# | mse           | 0.108    |
# | param_norm    | 80.3     |
# | samples       | 8.67e+03 |
# | step          | 270      |
# | vb            | 0.0619   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.578    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.102    |
# | mse           | 0.1      |
# | param_norm    | 80.3     |
# | samples       | 8.99e+03 |
# | step          | 280      |
# | vb            | 0.00225  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.656    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.181    |
# | mse           | 0.11     |
# | param_norm    | 80.3     |
# | samples       | 9.31e+03 |
# | step          | 290      |
# | vb            | 0.0708   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.784    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.108    |
# | mse           | 0.101    |
# | param_norm    | 80.3     |
# | samples       | 9.63e+03 |
# | step          | 300      |
# | vb            | 0.00753  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.565    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.102    |
# | mse           | 0.0968   |
# | param_norm    | 80.3     |
# | samples       | 9.95e+03 |
# | step          | 310      |
# | vb            | 0.00487  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.519    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.144    |
# | mse           | 0.0863   |
# | param_norm    | 80.3     |
# | samples       | 1.03e+04 |
# | step          | 320      |
# | vb            | 0.0576   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.554    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.0939   |
# | mse           | 0.0906   |
# | param_norm    | 80.3     |
# | samples       | 1.06e+04 |
# | step          | 330      |
# | vb            | 0.00324  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.454    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.135    |
# | mse           | 0.0878   |
# | param_norm    | 80.3     |
# | samples       | 1.09e+04 |
# | step          | 340      |
# | vb            | 0.0468   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.478    |
# | lg_loss_scale | 20.3     |
# | loss          | 0.136    |
# | mse           | 0.0919   |
# | param_norm    | 80.3     |
# | samples       | 1.12e+04 |
# | step          | 350      |
# | vb            | 0.0437   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.623    |
# | lg_loss_scale | 20.4     |
# | loss          | 0.085    |
# | mse           | 0.0829   |
# | param_norm    | 80.3     |
# | samples       | 1.16e+04 |
# | step          | 360      |
# | vb            | 0.0021   |
# ----------------------------
# Found NaN, decreased lg_loss_scale to 19.362000000000442
# ----------------------------
# | grad_norm     | 0.64     |
# | lg_loss_scale | 19.6     |
# | loss          | 0.168    |
# | mse           | 0.0918   |
# | param_norm    | 80.4     |
# | samples       | 1.19e+04 |
# | step          | 370      |
# | vb            | 0.0759   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.507    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0858   |
# | mse           | 0.0822   |
# | param_norm    | 80.4     |
# | samples       | 1.22e+04 |
# | step          | 380      |
# | vb            | 0.00359  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.446    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.113    |
# | mse           | 0.0742   |
# | param_norm    | 80.4     |
# | samples       | 1.25e+04 |
# | step          | 390      |
# | vb            | 0.0391   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.467    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.081    |
# | mse           | 0.0789   |
# | param_norm    | 80.4     |
# | samples       | 1.28e+04 |
# | step          | 400      |
# | vb            | 0.00211  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.428    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0813   |
# | mse           | 0.0782   |
# | param_norm    | 80.4     |
# | samples       | 1.32e+04 |
# | step          | 410      |
# | vb            | 0.00302  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.592    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.206    |
# | mse           | 0.0806   |
# | param_norm    | 80.4     |
# | samples       | 1.35e+04 |
# | step          | 420      |
# | vb            | 0.126    |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.607    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0863   |
# | mse           | 0.079    |
# | param_norm    | 80.4     |
# | samples       | 1.38e+04 |
# | step          | 430      |
# | vb            | 0.00723  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.773    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0775   |
# | mse           | 0.0757   |
# | param_norm    | 80.4     |
# | samples       | 1.41e+04 |
# | step          | 440      |
# | vb            | 0.00181  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.597    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0794   |
# | mse           | 0.0753   |
# | param_norm    | 80.4     |
# | samples       | 1.44e+04 |
# | step          | 450      |
# | vb            | 0.00401  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.445    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.096    |
# | mse           | 0.0662   |
# | param_norm    | 80.4     |
# | samples       | 1.48e+04 |
# | step          | 460      |
# | vb            | 0.0298   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.376    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0692   |
# | mse           | 0.0676   |
# | param_norm    | 80.4     |
# | samples       | 1.51e+04 |
# | step          | 470      |
# | vb            | 0.00162  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.47     |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0792   |
# | mse           | 0.0732   |
# | param_norm    | 80.4     |
# | samples       | 1.54e+04 |
# | step          | 480      |
# | vb            | 0.00604  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.474    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.101    |
# | mse           | 0.0706   |
# | param_norm    | 80.4     |
# | samples       | 1.57e+04 |
# | step          | 490      |
# | vb            | 0.0301   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.516    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0676   |
# | mse           | 0.0658   |
# | param_norm    | 80.4     |
# | samples       | 1.6e+04  |
# | step          | 500      |
# | vb            | 0.00173  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.439    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0909   |
# | mse           | 0.0665   |
# | param_norm    | 80.4     |
# | samples       | 1.64e+04 |
# | step          | 510      |
# | vb            | 0.0244   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.576    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0761   |
# | mse           | 0.0714   |
# | param_norm    | 80.4     |
# | samples       | 1.67e+04 |
# | step          | 520      |
# | vb            | 0.00462  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.611    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0844   |
# | mse           | 0.0759   |
# | param_norm    | 80.5     |
# | samples       | 1.7e+04  |
# | step          | 530      |
# | vb            | 0.00841  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.491    |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0768   |
# | mse           | 0.0701   |
# | param_norm    | 80.5     |
# | samples       | 1.73e+04 |
# | step          | 540      |
# | vb            | 0.00671  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.31     |
# | lg_loss_scale | 19.5     |
# | loss          | 0.0627   |
# | mse           | 0.0605   |
# | param_norm    | 80.5     |
# | samples       | 1.76e+04 |
# | step          | 550      |
# | vb            | 0.00229  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.471    |
# | lg_loss_scale | 19.6     |
# | loss          | 0.0697   |
# | mse           | 0.0667   |
# | param_norm    | 80.5     |
# | samples       | 1.8e+04  |
# | step          | 560      |
# | vb            | 0.00302  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.535    |
# | lg_loss_scale | 19.6     |
# | loss          | 0.0728   |
# | mse           | 0.0681   |
# | param_norm    | 80.5     |
# | samples       | 1.83e+04 |
# | step          | 570      |
# | vb            | 0.00471  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.356    |
# | lg_loss_scale | 19.6     |
# | loss          | 0.0621   |
# | mse           | 0.0605   |
# | param_norm    | 80.5     |
# | samples       | 1.86e+04 |
# | step          | 580      |
# | vb            | 0.00156  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.398    |
# | lg_loss_scale | 19.6     |
# | loss          | 0.0634   |
# | mse           | 0.0609   |
# | param_norm    | 80.5     |
# | samples       | 1.89e+04 |
# | step          | 590      |
# | vb            | 0.00253  |
# ----------------------------
# Found NaN, decreased lg_loss_scale to 18.599000000000732
# ----------------------------
# | grad_norm     | 0.748    |
# | lg_loss_scale | 19.6     |
# | loss          | 0.0662   |
# | mse           | 0.0643   |
# | param_norm    | 80.5     |
# | samples       | 1.92e+04 |
# | step          | 600      |
# | vb            | 0.00195  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.642    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0661   |
# | mse           | 0.0622   |
# | param_norm    | 80.5     |
# | samples       | 1.96e+04 |
# | step          | 610      |
# | vb            | 0.00386  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.408    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0828   |
# | mse           | 0.0594   |
# | param_norm    | 80.5     |
# | samples       | 1.99e+04 |
# | step          | 620      |
# | vb            | 0.0234   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.371    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0571   |
# | mse           | 0.0559   |
# | param_norm    | 80.5     |
# | samples       | 2.02e+04 |
# | step          | 630      |
# | vb            | 0.00126  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.409    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0589   |
# | mse           | 0.0571   |
# | param_norm    | 80.5     |
# | samples       | 2.05e+04 |
# | step          | 640      |
# | vb            | 0.00181  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.432    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0579   |
# | mse           | 0.0558   |
# | param_norm    | 80.5     |
# | samples       | 2.08e+04 |
# | step          | 650      |
# | vb            | 0.00213  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.705    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.066    |
# | mse           | 0.0633   |
# | param_norm    | 80.5     |
# | samples       | 2.12e+04 |
# | step          | 660      |
# | vb            | 0.00273  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.665    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0681   |
# | mse           | 0.0628   |
# | param_norm    | 80.5     |
# | samples       | 2.15e+04 |
# | step          | 670      |
# | vb            | 0.00538  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.533    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0652   |
# | mse           | 0.0633   |
# | param_norm    | 80.5     |
# | samples       | 2.18e+04 |
# | step          | 680      |
# | vb            | 0.0018   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.51     |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0627   |
# | mse           | 0.0598   |
# | param_norm    | 80.5     |
# | samples       | 2.21e+04 |
# | step          | 690      |
# | vb            | 0.00288  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.355    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0725   |
# | mse           | 0.0517   |
# | param_norm    | 80.5     |
# | samples       | 2.24e+04 |
# | step          | 700      |
# | vb            | 0.0208   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.366    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0787   |
# | mse           | 0.0565   |
# | param_norm    | 80.6     |
# | samples       | 2.28e+04 |
# | step          | 710      |
# | vb            | 0.0221   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.407    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0546   |
# | mse           | 0.0528   |
# | param_norm    | 80.6     |
# | samples       | 2.31e+04 |
# | step          | 720      |
# | vb            | 0.00183  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.45     |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0593   |
# | mse           | 0.0576   |
# | param_norm    | 80.6     |
# | samples       | 2.34e+04 |
# | step          | 730      |
# | vb            | 0.0017   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.373    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.054    |
# | mse           | 0.0528   |
# | param_norm    | 80.6     |
# | samples       | 2.37e+04 |
# | step          | 740      |
# | vb            | 0.00121  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.409    |
# | lg_loss_scale | 18.7     |
# | loss          | 0.0527   |
# | mse           | 0.0515   |
# | param_norm    | 80.6     |
# | samples       | 2.4e+04  |
# | step          | 750      |
# | vb            | 0.00119  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.522    |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0634   |
# | mse           | 0.0591   |
# | param_norm    | 80.6     |
# | samples       | 2.44e+04 |
# | step          | 760      |
# | vb            | 0.00428  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.499    |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0577   |
# | mse           | 0.0552   |
# | param_norm    | 80.6     |
# | samples       | 2.47e+04 |
# | step          | 770      |
# | vb            | 0.00255  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.7      |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0583   |
# | mse           | 0.056    |
# | param_norm    | 80.6     |
# | samples       | 2.5e+04  |
# | step          | 780      |
# | vb            | 0.00234  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.56     |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0809   |
# | mse           | 0.0585   |
# | param_norm    | 80.6     |
# | samples       | 2.53e+04 |
# | step          | 790      |
# | vb            | 0.0224   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.504    |
# | lg_loss_scale | 18.8     |
# | loss          | 0.058    |
# | mse           | 0.054    |
# | param_norm    | 80.6     |
# | samples       | 2.56e+04 |
# | step          | 800      |
# | vb            | 0.00401  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.428    |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0479   |
# | mse           | 0.047    |
# | param_norm    | 80.6     |
# | samples       | 2.6e+04  |
# | step          | 810      |
# | vb            | 0.000926 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.601    |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0609   |
# | mse           | 0.0569   |
# | param_norm    | 80.6     |
# | samples       | 2.63e+04 |
# | step          | 820      |
# | vb            | 0.00399  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.765    |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0775   |
# | mse           | 0.0588   |
# | param_norm    | 80.6     |
# | samples       | 2.66e+04 |
# | step          | 830      |
# | vb            | 0.0187   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.345    |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0503   |
# | mse           | 0.049    |
# | param_norm    | 80.6     |
# | samples       | 2.69e+04 |
# | step          | 840      |
# | vb            | 0.00135  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.4      |
# | lg_loss_scale | 18.8     |
# | loss          | 0.0518   |
# | mse           | 0.0493   |
# | param_norm    | 80.6     |
# | samples       | 2.72e+04 |
# | step          | 850      |
# | vb            | 0.00258  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.502    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0704   |
# | mse           | 0.0495   |
# | param_norm    | 80.6     |
# | samples       | 2.76e+04 |
# | step          | 860      |
# | vb            | 0.0209   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.399    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0657   |
# | mse           | 0.049    |
# | param_norm    | 80.6     |
# | samples       | 2.79e+04 |
# | step          | 870      |
# | vb            | 0.0167   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.327    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0658   |
# | mse           | 0.0496   |
# | param_norm    | 80.6     |
# | samples       | 2.82e+04 |
# | step          | 880      |
# | vb            | 0.0162   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.392    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0701   |
# | mse           | 0.0529   |
# | param_norm    | 80.6     |
# | samples       | 2.85e+04 |
# | step          | 890      |
# | vb            | 0.0172   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.286    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0459   |
# | mse           | 0.0449   |
# | param_norm    | 80.6     |
# | samples       | 2.88e+04 |
# | step          | 900      |
# | vb            | 0.000987 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.315    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0556   |
# | mse           | 0.0512   |
# | param_norm    | 80.7     |
# | samples       | 2.92e+04 |
# | step          | 910      |
# | vb            | 0.00439  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.481    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0494   |
# | mse           | 0.0472   |
# | param_norm    | 80.7     |
# | samples       | 2.95e+04 |
# | step          | 920      |
# | vb            | 0.00219  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.559    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.053    |
# | mse           | 0.0511   |
# | param_norm    | 80.7     |
# | samples       | 2.98e+04 |
# | step          | 930      |
# | vb            | 0.00189  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.393    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0487   |
# | mse           | 0.0476   |
# | param_norm    | 80.7     |
# | samples       | 3.01e+04 |
# | step          | 940      |
# | vb            | 0.00109  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.414    |
# | lg_loss_scale | 18.9     |
# | loss          | 0.0633   |
# | mse           | 0.0453   |
# | param_norm    | 80.7     |
# | samples       | 3.04e+04 |
# | step          | 950      |
# | vb            | 0.018    |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.368    |
# | lg_loss_scale | 19       |
# | loss          | 0.0475   |
# | mse           | 0.0467   |
# | param_norm    | 80.7     |
# | samples       | 3.08e+04 |
# | step          | 960      |
# | vb            | 0.00084  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.345    |
# | lg_loss_scale | 19       |
# | loss          | 0.0465   |
# | mse           | 0.0452   |
# | param_norm    | 80.7     |
# | samples       | 3.11e+04 |
# | step          | 970      |
# | vb            | 0.0013   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.565    |
# | lg_loss_scale | 19       |
# | loss          | 0.0656   |
# | mse           | 0.0499   |
# | param_norm    | 80.7     |
# | samples       | 3.14e+04 |
# | step          | 980      |
# | vb            | 0.0157   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.514    |
# | lg_loss_scale | 19       |
# | loss          | 0.0528   |
# | mse           | 0.0492   |
# | param_norm    | 80.7     |
# | samples       | 3.17e+04 |
# | step          | 990      |
# | vb            | 0.0036   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.595    |
# | lg_loss_scale | 19       |
# | loss          | 0.0532   |
# | mse           | 0.0495   |
# | param_norm    | 80.7     |
# | samples       | 3.2e+04  |
# | step          | 1e+03    |
# | vb            | 0.00365  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.359    |
# | lg_loss_scale | 19       |
# | loss          | 0.0564   |
# | mse           | 0.0432   |
# | param_norm    | 80.7     |
# | samples       | 3.24e+04 |
# | step          | 1.01e+03 |
# | vb            | 0.0132   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.41     |
# | lg_loss_scale | 19       |
# | loss          | 0.0663   |
# | mse           | 0.0496   |
# | param_norm    | 80.7     |
# | samples       | 3.27e+04 |
# | step          | 1.02e+03 |
# | vb            | 0.0166   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.418    |
# | lg_loss_scale | 19       |
# | loss          | 0.0508   |
# | mse           | 0.0465   |
# | param_norm    | 80.7     |
# | samples       | 3.3e+04  |
# | step          | 1.03e+03 |
# | vb            | 0.00434  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.665    |
# | lg_loss_scale | 19       |
# | loss          | 0.0477   |
# | mse           | 0.0463   |
# | param_norm    | 80.7     |
# | samples       | 3.33e+04 |
# | step          | 1.04e+03 |
# | vb            | 0.0014   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.672    |
# | lg_loss_scale | 19       |
# | loss          | 0.0732   |
# | mse           | 0.0528   |
# | param_norm    | 80.7     |
# | samples       | 3.36e+04 |
# | step          | 1.05e+03 |
# | vb            | 0.0204   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.779    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.065    |
# | mse           | 0.0586   |
# | param_norm    | 80.7     |
# | samples       | 3.4e+04  |
# | step          | 1.06e+03 |
# | vb            | 0.00647  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.429    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0435   |
# | mse           | 0.0426   |
# | param_norm    | 80.7     |
# | samples       | 3.43e+04 |
# | step          | 1.07e+03 |
# | vb            | 0.000895 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.46     |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0467   |
# | mse           | 0.0451   |
# | param_norm    | 80.7     |
# | samples       | 3.46e+04 |
# | step          | 1.08e+03 |
# | vb            | 0.00157  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.397    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0512   |
# | mse           | 0.0488   |
# | param_norm    | 80.7     |
# | samples       | 3.49e+04 |
# | step          | 1.09e+03 |
# | vb            | 0.00235  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.719    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0569   |
# | mse           | 0.0533   |
# | param_norm    | 80.7     |
# | samples       | 3.52e+04 |
# | step          | 1.1e+03  |
# | vb            | 0.00362  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.692    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0494   |
# | mse           | 0.0474   |
# | param_norm    | 80.8     |
# | samples       | 3.56e+04 |
# | step          | 1.11e+03 |
# | vb            | 0.00208  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.468    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0406   |
# | mse           | 0.0399   |
# | param_norm    | 80.8     |
# | samples       | 3.59e+04 |
# | step          | 1.12e+03 |
# | vb            | 0.000626 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.506    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0654   |
# | mse           | 0.0478   |
# | param_norm    | 80.8     |
# | samples       | 3.62e+04 |
# | step          | 1.13e+03 |
# | vb            | 0.0176   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.442    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0545   |
# | mse           | 0.0492   |
# | param_norm    | 80.8     |
# | samples       | 3.65e+04 |
# | step          | 1.14e+03 |
# | vb            | 0.00529  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.559    |
# | lg_loss_scale | 19.1     |
# | loss          | 0.0525   |
# | mse           | 0.0491   |
# | param_norm    | 80.8     |
# | samples       | 3.68e+04 |
# | step          | 1.15e+03 |
# | vb            | 0.00336  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.683    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0455   |
# | mse           | 0.0444   |
# | param_norm    | 80.8     |
# | samples       | 3.72e+04 |
# | step          | 1.16e+03 |
# | vb            | 0.00106  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.411    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0604   |
# | mse           | 0.0463   |
# | param_norm    | 80.8     |
# | samples       | 3.75e+04 |
# | step          | 1.17e+03 |
# | vb            | 0.0141   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.322    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0569   |
# | mse           | 0.0428   |
# | param_norm    | 80.8     |
# | samples       | 3.78e+04 |
# | step          | 1.18e+03 |
# | vb            | 0.0142   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.361    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0494   |
# | mse           | 0.0447   |
# | param_norm    | 80.8     |
# | samples       | 3.81e+04 |
# | step          | 1.19e+03 |
# | vb            | 0.0047   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.383    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0562   |
# | mse           | 0.0438   |
# | param_norm    | 80.8     |
# | samples       | 3.84e+04 |
# | step          | 1.2e+03  |
# | vb            | 0.0124   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.447    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0531   |
# | mse           | 0.0495   |
# | param_norm    | 80.8     |
# | samples       | 3.88e+04 |
# | step          | 1.21e+03 |
# | vb            | 0.00366  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.721    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0639   |
# | mse           | 0.0474   |
# | param_norm    | 80.8     |
# | samples       | 3.91e+04 |
# | step          | 1.22e+03 |
# | vb            | 0.0165   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.565    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0536   |
# | mse           | 0.0494   |
# | param_norm    | 80.8     |
# | samples       | 3.94e+04 |
# | step          | 1.23e+03 |
# | vb            | 0.00415  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.371    |
# | lg_loss_scale | 19.2     |
# | loss          | 0.055    |
# | mse           | 0.0432   |
# | param_norm    | 80.8     |
# | samples       | 3.97e+04 |
# | step          | 1.24e+03 |
# | vb            | 0.0117   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.5      |
# | lg_loss_scale | 19.2     |
# | loss          | 0.0457   |
# | mse           | 0.0442   |
# | param_norm    | 80.8     |
# | samples       | 4e+04    |
# | step          | 1.25e+03 |
# | vb            | 0.00154  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.405    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0479   |
# | mse           | 0.044    |
# | param_norm    | 80.8     |
# | samples       | 4.04e+04 |
# | step          | 1.26e+03 |
# | vb            | 0.00394  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.535    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0594   |
# | mse           | 0.0439   |
# | param_norm    | 80.8     |
# | samples       | 4.07e+04 |
# | step          | 1.27e+03 |
# | vb            | 0.0156   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.403    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0421   |
# | mse           | 0.0409   |
# | param_norm    | 80.8     |
# | samples       | 4.1e+04  |
# | step          | 1.28e+03 |
# | vb            | 0.00114  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.433    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0472   |
# | mse           | 0.0432   |
# | param_norm    | 80.8     |
# | samples       | 4.13e+04 |
# | step          | 1.29e+03 |
# | vb            | 0.00406  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.259    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0372   |
# | mse           | 0.0364   |
# | param_norm    | 80.8     |
# | samples       | 4.16e+04 |
# | step          | 1.3e+03  |
# | vb            | 0.000796 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.393    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0692   |
# | mse           | 0.0429   |
# | param_norm    | 80.8     |
# | samples       | 4.2e+04  |
# | step          | 1.31e+03 |
# | vb            | 0.0263   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.595    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0526   |
# | mse           | 0.0413   |
# | param_norm    | 80.9     |
# | samples       | 4.23e+04 |
# | step          | 1.32e+03 |
# | vb            | 0.0113   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.67     |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0513   |
# | mse           | 0.046    |
# | param_norm    | 80.9     |
# | samples       | 4.26e+04 |
# | step          | 1.33e+03 |
# | vb            | 0.00535  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.474    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.046    |
# | mse           | 0.044    |
# | param_norm    | 80.9     |
# | samples       | 4.29e+04 |
# | step          | 1.34e+03 |
# | vb            | 0.00203  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.498    |
# | lg_loss_scale | 19.3     |
# | loss          | 0.0486   |
# | mse           | 0.0448   |
# | param_norm    | 80.9     |
# | samples       | 4.32e+04 |
# | step          | 1.35e+03 |
# | vb            | 0.00383  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.395    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0437   |
# | mse           | 0.0407   |
# | param_norm    | 80.9     |
# | samples       | 4.36e+04 |
# | step          | 1.36e+03 |
# | vb            | 0.00298  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.395    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.04     |
# | mse           | 0.0385   |
# | param_norm    | 80.9     |
# | samples       | 4.39e+04 |
# | step          | 1.37e+03 |
# | vb            | 0.00157  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.378    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0422   |
# | mse           | 0.039    |
# | param_norm    | 80.9     |
# | samples       | 4.42e+04 |
# | step          | 1.38e+03 |
# | vb            | 0.0032   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.36     |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0417   |
# | mse           | 0.0404   |
# | param_norm    | 80.9     |
# | samples       | 4.45e+04 |
# | step          | 1.39e+03 |
# | vb            | 0.00124  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.516    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0545   |
# | mse           | 0.0425   |
# | param_norm    | 80.9     |
# | samples       | 4.48e+04 |
# | step          | 1.4e+03  |
# | vb            | 0.012    |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.355    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0413   |
# | mse           | 0.0383   |
# | param_norm    | 80.9     |
# | samples       | 4.52e+04 |
# | step          | 1.41e+03 |
# | vb            | 0.00302  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.337    |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0387   |
# | mse           | 0.0379   |
# | param_norm    | 80.9     |
# | samples       | 4.55e+04 |
# | step          | 1.42e+03 |
# | vb            | 0.000832 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.43     |
# | lg_loss_scale | 19.4     |
# | loss          | 0.0423   |
# | mse           | 0.0405   |
# | param_norm    | 80.9     |
# | samples       | 4.58e+04 |
# | step          | 1.43e+03 |
# | vb            | 0.00181  |
# ----------------------------
# Found NaN, decreased lg_loss_scale to 18.430000000001748
# ----------------------------
# | grad_norm     | 0.454    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0473   |
# | mse           | 0.0434   |
# | param_norm    | 80.9     |
# | samples       | 4.61e+04 |
# | step          | 1.44e+03 |
# | vb            | 0.00388  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.626    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0626   |
# | mse           | 0.0467   |
# | param_norm    | 80.9     |
# | samples       | 4.64e+04 |
# | step          | 1.45e+03 |
# | vb            | 0.0159   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.671    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0502   |
# | mse           | 0.0459   |
# | param_norm    | 80.9     |
# | samples       | 4.68e+04 |
# | step          | 1.46e+03 |
# | vb            | 0.00436  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.472    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0506   |
# | mse           | 0.0384   |
# | param_norm    | 80.9     |
# | samples       | 4.71e+04 |
# | step          | 1.47e+03 |
# | vb            | 0.0122   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.512    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0517   |
# | mse           | 0.0472   |
# | param_norm    | 80.9     |
# | samples       | 4.74e+04 |
# | step          | 1.48e+03 |
# | vb            | 0.00455  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.494    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0559   |
# | mse           | 0.0406   |
# | param_norm    | 80.9     |
# | samples       | 4.77e+04 |
# | step          | 1.49e+03 |
# | vb            | 0.0153   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.371    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0419   |
# | mse           | 0.0389   |
# | param_norm    | 80.9     |
# | samples       | 4.8e+04  |
# | step          | 1.5e+03  |
# | vb            | 0.00308  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.36     |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0451   |
# | mse           | 0.0417   |
# | param_norm    | 80.9     |
# | samples       | 4.84e+04 |
# | step          | 1.51e+03 |
# | vb            | 0.00339  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.368    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0495   |
# | mse           | 0.0374   |
# | param_norm    | 80.9     |
# | samples       | 4.87e+04 |
# | step          | 1.52e+03 |
# | vb            | 0.0121   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.414    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0535   |
# | mse           | 0.0394   |
# | param_norm    | 80.9     |
# | samples       | 4.9e+04  |
# | step          | 1.53e+03 |
# | vb            | 0.0142   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.47     |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0434   |
# | mse           | 0.0397   |
# | param_norm    | 80.9     |
# | samples       | 4.93e+04 |
# | step          | 1.54e+03 |
# | vb            | 0.00375  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.484    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0594   |
# | mse           | 0.0456   |
# | param_norm    | 81       |
# | samples       | 4.96e+04 |
# | step          | 1.55e+03 |
# | vb            | 0.0138   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.43     |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0405   |
# | mse           | 0.0383   |
# | param_norm    | 81       |
# | samples       | 5e+04    |
# | step          | 1.56e+03 |
# | vb            | 0.00221  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.417    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0386   |
# | mse           | 0.0373   |
# | param_norm    | 81       |
# | samples       | 5.03e+04 |
# | step          | 1.57e+03 |
# | vb            | 0.00134  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.498    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0441   |
# | mse           | 0.041    |
# | param_norm    | 81       |
# | samples       | 5.06e+04 |
# | step          | 1.58e+03 |
# | vb            | 0.00317  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.575    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0423   |
# | mse           | 0.0409   |
# | param_norm    | 81       |
# | samples       | 5.09e+04 |
# | step          | 1.59e+03 |
# | vb            | 0.00149  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.475    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0676   |
# | mse           | 0.0429   |
# | param_norm    | 81       |
# | samples       | 5.12e+04 |
# | step          | 1.6e+03  |
# | vb            | 0.0247   |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.404    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0392   |
# | mse           | 0.0382   |
# | param_norm    | 81       |
# | samples       | 5.16e+04 |
# | step          | 1.61e+03 |
# | vb            | 0.00102  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.353    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0378   |
# | mse           | 0.0369   |
# | param_norm    | 81       |
# | samples       | 5.19e+04 |
# | step          | 1.62e+03 |
# | vb            | 0.000929 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.413    |
# | lg_loss_scale | 18.6     |
# | loss          | 0.0425   |
# | mse           | 0.0387   |
# | param_norm    | 81       |
# | samples       | 5.22e+04 |
# | step          | 1.63e+03 |
# | vb            | 0.00384  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.364    |
# | lg_loss_scale | 18.6     |
# ...
# | mse           | 0.0104   |
# | param_norm    | 94.4     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.000235 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.191    |
# | lg_loss_scale | 18.1     |
# | loss          | 0.0154   |
# | mse           | 0.0117   |
# | param_norm    | 94.4     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.00366  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.162    |
# | lg_loss_scale | 18.1     |
# | loss          | 0.0109   |
# | mse           | 0.0107   |
# | param_norm    | 94.4     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.000269 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.16     |
# | lg_loss_scale | 18.1     |
# | loss          | 0.0141   |
# | mse           | 0.0109   |
# | param_norm    | 94.4     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.00318  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.197    |
# | lg_loss_scale | 18.1     |
# | loss          | 0.011    |
# | mse           | 0.0108   |
# | param_norm    | 94.4     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.000263 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.118    |
# | lg_loss_scale | 18.1     |
# | loss          | 0.0101   |
# | mse           | 0.01     |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.000111 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.177    |
# | lg_loss_scale | 18.1     |
# | loss          | 0.0115   |
# | mse           | 0.0102   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.00136  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.184    |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0104   |
# | mse           | 0.0102   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.000241 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.17     |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0109   |
# | mse           | 0.0105   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.000433 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.22     |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0139   |
# | mse           | 0.0112   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.00266  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.173    |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0115   |
# | mse           | 0.00987  |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.62e+04 |
# | vb            | 0.00166  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.376    |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0144   |
# | mse           | 0.0112   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.00324  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.349    |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0143   |
# | mse           | 0.0123   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.00208  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.24     |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0122   |
# | mse           | 0.0117   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.000488 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.183    |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0113   |
# | mse           | 0.011    |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.000319 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.203    |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0122   |
# | mse           | 0.0106   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.00167  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.114    |
# | lg_loss_scale | 18.2     |
# | loss          | 0.0101   |
# | mse           | 0.00993  |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.000122 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.189    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0126   |
# | mse           | 0.0108   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.00179  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.144    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0114   |
# | mse           | 0.0103   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.00111  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.0981   |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0147   |
# | mse           | 0.0103   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.63e+04 |
# | vb            | 0.00438  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.161    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0129   |
# | mse           | 0.0111   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.64e+04 |
# | vb            | 0.00177  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.238    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0132   |
# | mse           | 0.0117   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.64e+04 |
# | vb            | 0.00151  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.269    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0169   |
# | mse           | 0.0112   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.64e+04 |
# | vb            | 0.00576  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.152    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0108   |
# | mse           | 0.0104   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.64e+04 |
# | vb            | 0.000411 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.199    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0131   |
# | mse           | 0.0113   |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.64e+04 |
# | vb            | 0.00185  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.156    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0119   |
# | mse           | 0.00962  |
# | param_norm    | 94.5     |
# | samples       | 1.8e+06  |
# | step          | 5.64e+04 |
# | vb            | 0.00225  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.206    |
# | lg_loss_scale | 18.3     |
# | loss          | 0.0125   |
# | mse           | 0.011    |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.64e+04 |
# | vb            | 0.00148  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.231    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0134   |
# | mse           | 0.0107   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.64e+04 |
# | vb            | 0.00268  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.359    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0128   |
# | mse           | 0.0119   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.64e+04 |
# | vb            | 0.000891 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.13     |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0103   |
# | mse           | 0.0102   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.64e+04 |
# | vb            | 0.000142 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.186    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.012    |
# | mse           | 0.0114   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.64e+04 |
# | vb            | 0.000619 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.115    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0121   |
# | mse           | 0.0108   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.00137  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.152    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0111   |
# | mse           | 0.0106   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.000496 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.231    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0122   |
# | mse           | 0.0109   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.00135  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.121    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0104   |
# | mse           | 0.0103   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.000104 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.125    |
# | lg_loss_scale | 18.4     |
# | loss          | 0.0103   |
# | mse           | 0.0102   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.000135 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.0987   |
# | lg_loss_scale | 18.4     |
# | loss          | 0.00924  |
# | mse           | 0.00913  |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.000113 |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.178    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0124   |
# | mse           | 0.0103   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.00204  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.249    |
# | lg_loss_scale | 18.5     |
# | loss          | 0.0134   |
# | mse           | 0.0115   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.00193  |
# ----------------------------
# Found NaN, decreased lg_loss_scale to 17.47600000006902
# ----------------------------
# | grad_norm     | 0.206    |
# | lg_loss_scale | 17.9     |
# | loss          | 0.0139   |
# | mse           | 0.0122   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.65e+04 |
# | vb            | 0.00169  |
# ----------------------------
# ----------------------------
# | grad_norm     | 0.146    |
# | lg_loss_scale | 17.5     |
# | loss          | 0.0107   |
# | mse           | 0.0105   |
# | param_norm    | 94.5     |
# | samples       | 1.81e+06 |
# | step          | 5.66e+04 |
# | vb            | 0.000152 |
# ----------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File D:\Diff_Topo\开源\topodiff-main\scripts\image_train.py:82
#      78     return parser
#      81 if __name__ == "__main__":
# ---> 82     main()
#
# File D:\Diff_Topo\开源\topodiff-main\scripts\image_train.py:56, in main()
#      33 data = load_data(
#      34     data_dir=args.data_dir,
#      35     batch_size=args.batch_size,
#      36     image_size=args.image_size,
#      37 )
#      39 logger.log("training...")
#      40 TrainLoop(
#      41     model=model,
#      42     diffusion=diffusion,
#      43     data=data,
#      44     batch_size=args.batch_size,
#      45     microbatch=args.microbatch,
#      46     lr=args.lr,
#      47     ema_rate=args.ema_rate,
#      48     log_interval=args.log_interval,
#      49     save_interval=args.save_interval,
#      50     resume_checkpoint=args.resume_checkpoint,
#      51     use_fp16=args.use_fp16,
#      52     fp16_scale_growth=args.fp16_scale_growth,
#      53     schedule_sampler=schedule_sampler,
#      54     weight_decay=args.weight_decay,
#      55     lr_anneal_steps=args.lr_anneal_steps,
# ---> 56 ).run_loop()
#
# File D:\Diff_Topo\开源\topodiff-main\topodiff\train_util.py:140, in TrainLoop.run_loop(self)
#     135 while (
#     136     not self.lr_anneal_steps
#     137     or self.step + self.resume_step < self.lr_anneal_steps
#     138 ):
#     139     batch, batch_cons, _ = next(self.data)
# --> 140     self.run_step(batch, batch_cons)
#     141     if self.step % self.log_interval == 0:
#     142         logger.dumpkvs()
#
# File D:\Diff_Topo\开源\topodiff-main\topodiff\train_util.py:154, in TrainLoop.run_step(self, batch, batch_cons)
#     153 def run_step(self, batch, batch_cons):
# --> 154     self.forward_backward(batch, batch_cons)
#     155     took_step = self.mp_trainer.optimize(self.opt)
#     156     if took_step:
#
# File D:\Diff_Topo\开源\topodiff-main\topodiff\train_util.py:193, in TrainLoop.forward_backward(self, batch, batch_cons)
#     189 loss = (losses["loss"] * weights).mean()
#     190 log_loss_dict(
#     191     self.diffusion, t, {k: v * weights for k, v in losses.items()}
#     192 )
# --> 193 self.mp_trainer.backward(loss)
#
# File D:\Diff_Topo\开源\topodiff-main\topodiff\fp16_util.py:179, in MixedPrecisionTrainer.backward(self, loss)
#     177 if self.use_fp16:
#     178     loss_scale = 2 ** self.lg_loss_scale
# --> 179     (loss * loss_scale).backward()
#     180 else:
#     181     loss.backward()
#
# File D:\AnacondaAPP\envs\1_jupyter_model_train\lib\site-packages\torch\_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)
#     629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File D:\AnacondaAPP\envs\1_jupyter_model_train\lib\site-packages\torch\autograd\__init__.py:381, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     376     retain_graph = create_graph
#     378 # The reason we repeat the same comment below is that
#     379 # some Python versions print out the first line of a multi-line function
#     380 # calls in the traceback and some print out the last line
# --> 381 _engine_run_backward(
#     382     tensors,
#     383     grad_tensors_,
#     384     retain_graph,
#     385     create_graph,
#     386     inputs_tuple,
#     387     allow_unreachable=True,
#     388     accumulate_grad=True,
#     389 )
#
# File D:\AnacondaAPP\envs\1_jupyter_model_train\lib\site-packages\torch\autograd\graph.py:869, in _engine_run_backward(t_outputs, *args, **kwargs)
#     867     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     868 try:
# --> 869     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     870         t_outputs, *args, **kwargs
#     871     )  # Calls into the C++ engine to run the backward pass
#     872 finally:
#     873     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# By the end of the training, you should get in the diff_logdir a series of checkpoints. You can then use the last checkpoint as the difusion model when sampling from TopoDiff (see the notebook **4_TopoDiff_sample**).
